# %%
import pandas as pd
data=pd.read_csv("C:/Users/raghu/Downloads/ev-charging-stations-india.csv")
data
# Out:
#                                                    name          state  \
# 0                    Neelkanth Star DC Charging Station        Haryana
# 1                          Galleria DC Charging Station        Haryana
# 2     Highway Xpress (Jaipur-Delhi) DC charging station      Rajasthan
# 3                     Food Carnival DC Charging Station  Uttar Pradesh
# 4                     Food Carnival AC Charging Station  Uttar Pradesh
# ...                                                 ...            ...
# 1542                                        Tata Power          Kerala
# 1543                                        Tata Power         Haryana
# 1544                                        Tata Power         Haryana
# 1545                                        Tata Power           Jammu
# 1546                                        Tata Power       Karnataka
#
#            city                                            address  \
# 0      Gurugram  Neelkanth Star Karnal, NH 44, Gharunda, Kutail...
# 1      Gurugram  DLF Phase IV, Sector 28, Gurugram, Haryana 122022
# 2        Behror  Jaipur to Delhi Road, Behror Midway, Behror, R...
# 3      Khatauli  Fun and Food Carnival, NH 58, Khatauli Bypass,...
# 4      Khatauli  NH 58, Khatauli Bypass, Bhainsi, Uttar Pradesh...
# ...         ...                                                ...
# 1542     Munnar  Gokulam Park Munnar, Power House Road, South C...
# 1543    Gurgaon  Vatika Town Square II, Sector 82, Sector 82, V...
# 1544    Gurgaon  Zedex TATA, Sec 48, GF-26, NIHO Scottish Mall,...
# 1545      Jammu  Le ROI, Jammu, Railway Station, Jammu, Jammu &...
# 1546  Mangalore  Auto Matrix, Bejai, Manjusha Building, Bejai, ...
#
#        lattitude  longitude  type
# 0        29.6019  76.980300  12.0
# 1        28.4673  77.081800  12.0
# 2        27.8751  76.276000  12.0
# 3        29.3105  77.721800  12.0
# 4        29.3105  77.721800  12.0
# ...          ...        ...   ...
# 1542  10.0297934  77.045859   7.0
# 1543  28.3904593  76.959200   7.0
# 1544   28.411072  77.040546   7.0
# 1545  32.7064117  74.879203   7.0
# 1546   12.885716  74.843476   7.0
#
# [1547 rows x 7 columns]

# %%
data.describe()
# Out:
#           longitude         type
# count  1.541000e+03  1539.000000
# mean   1.105323e+05     9.020793
# std    3.064996e+06     4.136436
# min    8.058454e+00     6.000000
# 25%    7.562036e+01     7.000000
# 50%    7.721257e+01     7.000000
# 75%    7.847983e+01    11.000000
# max    8.510551e+07    24.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1547 entries, 0 to 1546
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       1547 non-null   object
#  1   state      1547 non-null   object
#  2   city       1547 non-null   object
#  3   address    1507 non-null   object
#  4   lattitude  1541 non-null   object
#  5   longitude  1541 non-null   float64
#  6   type       1539 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 84.7+ KB

# %%
import numpy as np
print(data["state"].unique())
print("enter total no of states: ",np.size(data["state"].unique()))
# Out:
# ['Haryana' 'Rajasthan' 'Uttar Pradesh' 'Himachal Pradesh' 'Maharashtra'
#  'Delhi' 'Tamil Nadu' 'Uttarakhand' 'Gujarat' 'Goa' 'Telangana'
#  'Karnataka' 'Punjab' 'Jammu and Kashmir' 'Odisha' 'Pondicherry'
#  'TamilNadu' 'Uttrakhand' 'WestBengal' 'Harayana' 'Chandigarh'
#  'Hyderabadu00a0' 'Kerala' 'AndhraPradesh' 'TamiNadu' 'Jharkhand' 'Bihar'
#  'West Bengal' 'Jammu' 'Andhra Pradesh' 'Chhattisgarh' 'Madhya Pradesh'
#  'Andhra pradesh' 'Puducherry' 'Jammu & Kashmir' 'Assam' 'Sikkim'
#  'Uttarakhand ' 'TAMIL NADU' 'Andhra Pradesh ' 'Bhubhaneswar'
#  'Chattisgarh' 'chattisgarh' 'Chikhali' 'Delhi NCR' 'Ernakulam' 'Hisar'
#  'Hyderabad' 'Jajpur' 'Kochi' 'Limbdi' 'Maharashra' 'PUNJAB' 'Rajahmundry'
#  'TELENGANA' 'Uttarkhand' 'Andra Pradesh' 'Karala' 'Tripura' 'Andaman']
# enter total no of states:  60

# %%
data["state"] = data['state'].replace(['AndhraPradesh'],'Andhra Pradesh')
data["state"] = data['state'].replace(['Andra Pradesh'],'Andhra Pradesh')
data["state"] = data['state'].replace(['Andra Pradesh '],'Andhra Pradesh')
data["state"] = data['state'].replace(['Andhra Pradesh '],'Andhra Pradesh')
data["state"] = data['state'].replace(['Andhra pradesh '],'Andhra Pradesh')
data["state"] = data['state'].replace(['Andhra pradesh'],'Andhra Pradesh')
data["state"] = data['state'].replace(['Rajahmundry'],'Andhra Pradesh')
data["state"] = data['state'].replace(['Bhubhaneswar'],'Odisha')
data["state"] = data['state'].replace(['Jammu'],'Jammu and Kashmir')
data["state"] = data['state'].replace(['Jammu & Kashmir'],'Jammu and Kashmir')
data["state"] = data['state'].replace(['TamiNadu'],'TamilNadu')
data["state"] = data['state'].replace(['Tamil Nadu'],'TamilNadu')
data["state"] = data['state'].replace(['TAMIL NADU'],'TamilNadu')
data["state"] = data['state'].replace(['Uttarkhand'],'Uttarakhand')
data["state"] = data['state'].replace(['Uttrakhand'],'Uttarakhand')
data["state"] = data['state'].replace(['Uttarakhand '],'Uttarakhand')
data["state"] = data['state'].replace(['Maharashra'],'Maharashtra')
data["state"] = data['state'].replace(['Chikhali'],'Maharashtra')
data["state"] = data['state'].replace(['Hyderabad'],'Telangana')
data["state"] = data['state'].replace(['Hyderabadu00a0'],'Telangana')
data["state"] = data['state'].replace(['TELENGANA'],'Telangana')
data["state"] = data['state'].replace(['Karala'],'Kerala')
data["state"] = data['state'].replace(['Ernakulam'],'Kerala')
data["state"] = data['state'].replace(['Kochi'],'Kerala')
data["state"] = data['state'].replace(['chattisgarh'],'Chhattisgarh')
data["state"] = data['state'].replace(['Chattisgarh'],'Chhattisgarh')
data["state"] = data['state'].replace(['Bhubhaneswar'],'Odisha')
data["state"] = data['state'].replace(['PUNJAB'],'Punjab')
data["state"] = data['state'].replace(['Jajpur'],'Jaipur')
data["state"] = data['state'].replace(['Harayana'],'Haryana')
data["state"] = data['state'].replace(['Hisar'],'Haryana')
data["state"] = data['state'].replace(['Delhi NCR'],'Delhi')
data["state"] = data['state'].replace(['WestBengal'],'West Bengal')
data["state"] = data['state'].replace(['Limbdi'],'Gujarat')
data["state"] = data['state'].replace(['Tripura'],'Agartala')

# %%
print(data["state"].unique())
print("enter total no of states: ",np.size(data["state"].unique()))
# Out:
# ['Haryana' 'Rajasthan' 'Uttar Pradesh' 'Himachal Pradesh' 'Maharashtra'
#  'Delhi' 'TamilNadu' 'Uttarakhand' 'Gujarat' 'Goa' 'Telangana' 'Karnataka'
#  'Punjab' 'Jammu and Kashmir' 'Odisha' 'Pondicherry' 'West Bengal'
#  'Chandigarh' 'Kerala' 'Andhra Pradesh' 'Jharkhand' 'Bihar' 'Chhattisgarh'
#  'Madhya Pradesh' 'Puducherry' 'Assam' 'Sikkim' 'Jaipur' 'Agartala'
#  'Andaman']
# enter total no of states:  30

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig=plt.figure(figsize=(40,20))
sns.countplot(data["state"])
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\raghu\AppData\Local\Temp\ipykernel_35968\2849680482.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# States with more than 50 Electric Vehicle Charging Station

# %% [markdown]
# ANDHRA PRADESH

# %%
Ap_df=data[data["state"]=="Andhra Pradesh"]
Ap_df
# Out:
#                                                    name           state  \
# 165                                             TamTree  Andhra Pradesh
# 213                                     Nukkad Tea Cafe  Andhra Pradesh
# 234                                      Hotel Parktel   Andhra Pradesh
# 235                          Ardas Televentures Pvt Ltd  Andhra Pradesh
# 284                                   Abhay Graphics II  Andhra Pradesh
# 294                                  Sri Murugan Stores  Andhra Pradesh
# 356                                  The Coffee Stories  Andhra Pradesh
# 394                                Radisson Resort, ECR  Andhra Pradesh
# 396                                E Planet, Thalassery  Andhra Pradesh
# 397                                            Oyo Soho  Andhra Pradesh
# 398                                    M R A Restaurant  Andhra Pradesh
# 415                                       Akki's Bistro  Andhra Pradesh
# 459                  Matsya Amazon Kitchens, Kurnool Rd  Andhra Pradesh
# 529   Blue Moon Highway Restaurant, Bangalore-Hydera...  Andhra Pradesh
# 534            Aavas Hotels & Resorts, NH 16 Velampalli  Andhra Pradesh
# 540   IOCL - NAVABHARAGAVA FILLING STATION, Vijayawa...  Andhra Pradesh
# 546            Tristar Auto Agencies, RK Beach Junction  Andhra Pradesh
# 580   Highway Grand World, Chennai-Tirupati Highway ...  Andhra Pradesh
# 581   Hotel Sapthagiri Holiday Resorts,Tirupati u00e...  Andhra Pradesh
# 582   Hotel Sapthagiri Holiday Resorts,Tirupati u00e...  Andhra Pradesh
# 584          IOCL Sree Devi Prasad Services, Naamavaram  Andhra Pradesh
# 586                     Nandi Food Plaza, Nalagam palli  Andhra Pradesh
# 587                     River Bay Resorts, Gautami Ghat  Andhra Pradesh
# 604          IOCL - KOORAPATI SERVICE STATION, Tirupati  Andhra Pradesh
# 605             IOCL - Sai Krupa Filling Station, SH 26  Andhra Pradesh
# 610            Sasya Auto Cars, Bellari X Roads - NH 44  Andhra Pradesh
# 611       Sasya Automotives, Near EENADU Office - NH 44  Andhra Pradesh
# 617          PNR Function Hall, Chennai-Ballary Highway  Andhra Pradesh
# 877                             Bhimas Residency Hotel   Andhra Pradesh
# 879                                           Hotel JAS  Andhra Pradesh
# 920                              Hotel Bliss | Tirupati  Andhra Pradesh
# 921                             Bhimas Residency Hotel   Andhra Pradesh
# 922                         Jayalakshmi Auto, Gudavalli  Andhra Pradesh
# 923                      Garuda Food Court, Komirepalle  Andhra Pradesh
# 924                       Shiv Shanker Motors, Gajuwaka  Andhra Pradesh
# 925                   Shiv Shanker Motors, Kancharpalem  Andhra Pradesh
# 926   Croma u00e2u0080u0093 MVR Complex, Waltair Upl...  Andhra Pradesh
# 927   IOCL - NAVABHARAGAVA FILLING STATION, Vijayawa...  Andhra Pradesh
# 928   Highway Grand World, Chennai-Tirupati Highway ...  Andhra Pradesh
# 929   Hotel Sapthagiri Holiday Resorts,Tirupati u00e...  Andhra Pradesh
# 930   Hotel Sapthagiri Holiday Resorts,Tirupati u00e...  Andhra Pradesh
# 931          IOCL Sree Devi Prasad Services, Naamavaram  Andhra Pradesh
# 932                     Nandi Food Plaza, Nalagam palli  Andhra Pradesh
# 933                     River Bay Resorts, Gautami Ghat  Andhra Pradesh
# 934          IOCL - KOORAPATI SERVICE STATION, Tirupati  Andhra Pradesh
# 935             IOCL - Sai Krupa Filling Station, SH 26  Andhra Pradesh
# 936            Sasya Auto Cars, Bellari X Roads - NH 44  Andhra Pradesh
# 937       Sasya Automotives, Near EENADU Office - NH 44  Andhra Pradesh
# 938          PNR Function Hall, Chennai-Ballary Highway  Andhra Pradesh
# 939                            IOCL - TIRUMALA AGENCIES  Andhra Pradesh
# 940                                           Hotel JAS  Andhra Pradesh
# 1200                 Matsya Amazon Kitchens, Kurnool Rd  Andhra Pradesh
# 1202              Hotel Grand Leela Krishna, Bhimavaram  Andhra Pradesh
# 1240  Blue Moon Highway Restaurant, Bangalore-Hydera...  Andhra Pradesh
# 1243           Aavas Hotels & Resorts, NH 16 Velampalli  Andhra Pradesh
# 1246           Tristar Auto Agencies, RK Beach Junction  Andhra Pradesh
# 1252                         Daspalla Hotels, Suryabagh  Andhra Pradesh
# 1299                      Shiv Shanker Motors, Hukumpet  Andhra Pradesh
# 1449                                    Hotel Gangothri  Andhra Pradesh
# 1450                                Exotikka Restaurant  Andhra Pradesh
#
#                city                                            address  \
# 165            pune  Shop No.5, Pragati Bhavan, Behind Natural Ice ...
# 213          raipur  75, Jalvihar Colony Rd, Civil Lines, Raipur, C...
# 234       ghaziabad  Omaxe Plaza, 583, Vijay Laxmi Pandit Marg, Nea...
# 235          jaipur  #147, Rathore Nagar, Amrapali Road, Vaishali N...
# 284            pune  D-II, Plot no 32, Unit B - Near Kia Showroom, ...
# 294         chennai  9&10, Tejraj colony, Agaram Main Rd, Selaiyur,...
# 356            pune  2, Meher classic, shop no:2, opp N.K.Ashiyana ...
# 394         chennai                                                ECR
# 396          kannur       AVK Nair Road, Pilakool, Thalassery, Kerala
# 397           noida  D-141, Block D, Sector 51, Noida, Uttar Prades...
# 398          kannur  Kasaragod - Kannur Rd, Trichambaram, Taliparam...
# 415        kolhapur  CS No 1082, Chandrameela Building, Near Krishn...
# 459         Kurnool  NH 44; Bangalore - Hyderabad  highway, Kurnool...
# 529     Anantapuram  NH 44; Bangalore - Hyderabad  highway, 116/1B,...
# 534          Ongole  NH 16, Vijayawada - Nellore Hwy, Vellampalli (...
# 540      Vijayawada  Vijayawada - Hyderabad Hwy, Ibrahimpatnam, And...
# 546           Vizag  Beside Kali Matha Mandhir, RK Beach Junction, ...
# 580        Tirupati  Chennai - Thiruttani - Renigunta Hwy, NH716 - ...
# 581        Chittoor  NH140, Tirupati u00e2u0080u0093 Bangalore  Hig...
# 582         Gadanki            NH140, Gadanki, Andhra Pradesh - 517112
# 584      Naamavaram                  Naamavaram, Andhra Pradesh 531126
# 586        Chittoor  NH 69 - 174 Nalagampalli Chittoor-Bangalore Hi...
# 587     Rajahmundry  Hotel River Bay Resort, 5-1-36 to 43 Gautami G...
# 604        Tirupati  TIRUPATI URBAN AND MANDAL Air bye-pass road. T...
# 605       Anantapur  SH 26, Vajrakarur to Guntakal Road SURVEY No.4...
# 610         Kurnool  Renault Showroom, 45/142-70-5-B, NH44 Near APS...
# 611         Kurnool  Isuzu Showroom, Survey No-131-1 & 133-1A NH44 ...
# 617       Proddatur  D No 7/3109 Sy No 622, Beside IOCL petrol pump...
# 877        Tirupati       19-3-41 Renigunta Road, near Ramanuja Circle
# 879   Visakhapatnam  NH45 Kagitha Village Near Vempadu Toll Gate Na...
# 920       Tirupathi  Hotel Bliss, 19-3-45, Near Ramanuja Circle, Re...
# 921        Tirupati       19-3-41 Renigunta Road, near Ramanuja Circle
# 922      Vijayawada  Jayalakshmi Auto Enterprises Pvt Ltd, Survey n...
# 923     Komirepalle  NH 16 Gundugolanu, Komirepalle, Andhra Pradesh...
# 924           Vizag  Sobha Square, Vishwaswaraya Nagar, Gajuwaka, V...
# 925           Vizag  C 24, Industrail Estate, Kancharapalem, Vishak...
# 926           Vizag  Ground & First floor, MVR # 10-1-39/B&C, Sirip...
# 927      Vijayawada  Vijayawada - Hyderabad Hwy, Ibrahimpatnam, And...
# 928        Tirupati  Chennai - Thiruttani - Renigunta Hwy, NH716 - ...
# 929        Chittoor  NH140, Tirupati u00e2u0080u0093 Bangalore  Hig...
# 930         Gadanki            NH140, Gadanki, Andhra Pradesh - 517112
# 931      Naamavaram                  Naamavaram, Andhra Pradesh 531126
# 932        Chittoor  NH 69 - 174 Nalagampalli Chittoor-Bangalore Hi...
# 933     Rajahmundry  Hotel River Bay Resort, 5-1-36 to 43 Gautami G...
# 934        Tirupati  TIRUPATI URBAN AND MANDAL Air bye-pass road. T...
# 935       Anantapur  SH 26, Vajrakarur to Guntakal Road SURVEY No.4...
# 936         Kurnool  Renault Showroom, 45/142-70-5-B, NH44 Near APS...
# 937         Kurnool  Isuzu Showroom, Survey No-131-1 & 133-1A NH44 ...
# 938       Proddatur  D No 7/3109 Sy No 622, Beside IOCL petrol pump...
# 939      Peddapuram  Sy No 164, Peddapuram Bye-Pass Village/Mandal,...
# 940   Visakhapatnam  NH45 Kagitha Village Near Vempadu Toll Gate Na...
# 1200        Kurnool  NH 44; Bangalore - Hyderabad  highway, Kurnool...
# 1202     Bhimavaram  Undi Rd, Balusumoodi, Bhimavaram, Andhra Prade...
# 1240    Anantapuram  NH 44; Bangalore - Hyderabad  highway, 116/1B,...
# 1243         Ongole  NH 16, Vijayawada - Nellore Hwy, Vellampalli (...
# 1246          Vizag  Beside Kali Matha Mandhir, RK Beach Junction, ...
# 1252          Vizag  Hotel Daspalla Visakhapatnam, 28-2-48, Suryaba...
# 1299    Rajahmundry  110-4-7, NH 16 Hukumpet, Aditya Nagar, Bommuru...
# 1449      Kodikonda  Kodikonda Checkpost (V), Chilamathur (Mandal),...
# 1450     Ananthapur  survey no- 155, NH44, beside TATA show room. K...
#
#              lattitude  longitude  type
# 165         18.5231567  73.847693   6.0
# 213         21.2404762  81.657498   6.0
# 234         28.6463665  77.367840   6.0
# 235          26.911545  75.748760   6.0
# 284   18.6532425324259  73.803401   6.0
# 294         12.9056714  80.142139   6.0
# 356   18.4879225398295  73.872763   6.0
# 394         12.6238102  80.194767   6.0
# 396   11.7455443615496  75.495020   6.0
# 397           28.58066  77.374970   6.0
# 398   12.0256266201313  75.367177   6.0
# 415         16.6856931  74.208422   6.0
# 459          15.576915  77.937040   7.0
# 529           15.02395  77.620628   7.0
# 534         15.6382976  80.016753   7.0
# 540         16.5812639  80.526349   7.0
# 546        17.71241304  83.318481   7.0
# 580        13.29360934  79.581709   7.0
# 581        13.37412051  79.092103   7.0
# 582         13.4799438  79.189790   7.0
# 584         17.3736805  82.586259   7.0
# 586         13.2035919  78.941566   7.0
# 587         16.9921196  81.773577   7.0
# 604         13.6207096  79.382815   7.0
# 605         15.1462972  77.377456   7.0
# 610         15.8305662  78.017989   7.0
# 611         15.8498643  78.004500   7.0
# 617         14.7529922  78.555077   7.0
# 877        13.62754649  79.430564  19.0
# 879        17.39957297  82.681138  19.0
# 920         13.6253731  79.432233  11.0
# 921        13.62754649  79.430564  19.0
# 922         16.5129225  80.749757   7.0
# 923          16.778579  81.221054   7.0
# 924           17.68429  83.185923   7.0
# 925          17.738719  83.262580   7.0
# 926          17.725417  83.315175   7.0
# 927         16.5812639  80.526349   7.0
# 928        13.29360934  79.581709   7.0
# 929        13.37412051  79.092103   7.0
# 930         13.4799438  79.189790   7.0
# 931         17.3736805  82.586259   7.0
# 932         13.2035919  78.941566   7.0
# 933         16.9921196  81.773577   7.0
# 934         13.6207096  79.382815   7.0
# 935         15.1462972  77.377456   7.0
# 936         15.8305662  78.017989   7.0
# 937         15.8498643  78.004500   7.0
# 938         14.7529922  78.555077   7.0
# 939         17.0758862  82.121731   7.0
# 940        17.39957297  82.681138  19.0
# 1200         15.576915  77.937040   7.0
# 1202        16.5451748  81.519940   7.0
# 1240          15.02395  77.620628   7.0
# 1243        15.6382976  80.016753   7.0
# 1246       17.71241304  83.318481   7.0
# 1252        17.7105539  83.300827   7.0
# 1299        16.9833296  81.798043   7.0
# 1449             13.83  77.740000  21.0
# 1450             14.65  77.580000  21.0

# %%
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Ap_df["lattitude"],Ap_df["longitude"]).set(title="plotting the ev stations in ANDHRA PRADESH")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in ANDHRA PRADESH')]

# %%
ap_freq_li=pd.DataFrame(Ap_df["city"].value_counts())
ap_freq_li=ap_freq_li.head()
print(ap_freq_li)
# Out:
#              city
# Tirupati        6
# Kurnool         6
# Vizag           6
# Chittoor        4
# Rajahmundry     3

# %% [markdown]
# Maharashtra

# %%
maha_df=data[data["state"]=="Maharashtra"]
maha_df
# Out:
#                                          name        state        city  \
# 12    Synergy Solutions AC Charging Station 2  Maharashtra        Pune
# 19                   Kothari Enterprises  AC1  Maharashtra     Khopoli
# 22     Lonavla Wax Museum DC Charging Station  Maharashtra     Lonavla
# 32           Tellus Power DC Charging Station  Maharashtra        Pune
# 34    Synergy Solutions AC Charging Station 1  Maharashtra        Pune
# ...                                       ...          ...         ...
# 1524                              Tata Power   Maharashtra      Mumbai
# 1528                              Tata Power   Maharashtra      Mumbai
# 1537                              Tata Power   Maharashtra      Mumbai
# 1538                              Tata Power   Maharashtra       Chouk
# 1539                              Tata Power   Maharashtra  Ahmednagar
#
#                                                 address    lattitude  \
# 12    Synergy Solutions, Shop No 9 , Modak Prasad, 4...       18.538
# 19    Kothari Brothers, Laxminagar, Khopoli, Maharas...      18.7876
# 22    69/1 near Lonavla College, opp. neeta volvo, V...       18.763
# 32                             AH47, Maharashtra 415406      17.0749
# 34     office 9. Modak Prasad ,Oppo Rastrabhasha Bhavan      18.5145
# ...                                                 ...          ...
# 1524  Seven Hills Hospital, Andheri East, SevenHills...    19.118831
# 1528  IOCL Sahara Hospitality, Vile Parle, opp. Dome...    19.094122
# 1537  CR - Lokmanya Tilak Station, Kurla, Outside Pl...    19.068262
# 1538  Chowk Highway Service Centre, Old Mum-Pune hig...     18.90173
# 1539  Lilium Park, SH 44, Hotel Lilium Park State Hi...  19.26433634
#
#       longitude  type
# 12    73.848500  12.0
# 19    73.347500  12.0
# 22    73.425200  12.0
# 32    74.222700  12.0
# 34    73.848900  12.0
# ...         ...   ...
# 1524  72.878230   7.0
# 1528  72.852230   7.0
# 1537  72.890964   7.0
# 1538  73.234360   7.0
# 1539  74.827200   7.0
#
# [265 rows x 7 columns]

# %%
fig=plt.figure(figsize=(10,10))
sns.scatterplot(maha_df["lattitude"],maha_df["longitude"]).set(title="plotting the ev stations in Maharashtra")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Maharashtra')]

# %%
maha_freq_li=pd.DataFrame(maha_df["city"].value_counts())
maha_freq_li=maha_freq_li.head()
print(maha_freq_li)
# Out:
#              city
# Mumbai         45
# Pune           34
# Nashik         15
# bengaluru      12
# Navi Mumbai     7

# %%
delhi_df=data[data["state"]=="Delhi"]
print(delhi_df)
delhi_freq_li=pd.DataFrame(delhi_df["city"].value_counts())
delhi_freq_li=delhi_freq_li.head()
print(delhi_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(delhi_df["lattitude"],delhi_df["longitude"]).set(title="plotting the ev stations in Maharashtra")
maha_freq_li=pd.DataFrame(maha_df["city"].value_counts())
# Out:
#                                    name  state       city  \
# 13                 IOCL Rajokri Station  Delhi  New Delhi
# 16             IOCL Nehru Nagar Station  Delhi  New Delhi
# 17                    IOCL Mathura Road  Delhi  New Delhi
# 31    IOCL Dhaula Kuan Charging Station  Delhi  New Delhi
# 39    HP Pitam Pura DC Charging Station  Delhi  New Delhi
# ...                                 ...    ...        ...
# 1522                        Tata Power   Delhi      Delhi
# 1523                        Tata Power   Delhi      Delhi
# 1525                        Tata Power   Delhi      Delhi
# 1526                        Tata Power   Delhi      Delhi
# 1527                        Tata Power   Delhi      Delhi
#
#                                                 address   lattitude  \
# 13        NH 8 Exit 4, Samalka, New Delhi, Delhi 110037     28.5248
# 16    10-C, Nehru Nagar, Ring Rd, near Lajpat Nagar,...     28.5682
# 17    No A12, Mathura Rd, near Telephone Exchange, F...      28.566
# 31    Ring Rd, opposite Gurudwara, Smriti Vatika, No...     28.5874
# 39    HP PETROL PUMP - AUTO CARE CENTRE PITAM PURA, ...     28.6962
# ...                                                 ...         ...
# 1522  Parking Near Manglam Place, Rohini, MCD parkin...  28.6981417
# 1523  PVR Naraina, Commercial Complex, Community Cen...  28.6321091
# 1525  Ssensse Hotel, Sec 25, PLOT NO.28, POCKET 5A, ...   28.735847
# 1526  Tanga Stand, Moti Nagar, MCD Parking, Tanga St...  28.6591233
# 1527  Videocon Tower, Jhandewalan, E3/15, Block E3, ...  28.6449172
#
#       longitude  type
# 13    77.101000  12.0
# 16    77.253100  12.0
# 17    77.266400  12.0
# 31    77.171300  12.0
# 39    77.155000  12.0
# ...         ...   ...
# 1522  77.116451   7.0
# 1523  77.137268   7.0
# 1525  77.093263   7.0
# 1526  77.143639   7.0
# 1527  77.202513   7.0
#
# [179 rows x 7 columns]
#            city
# Delhi        70
# New Delhi    67
# Gurgaon       9
# NEW DELHI     6
# pune          3
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
TamilNadu_df=data[data["state"]=="TamilNadu"]
print(TamilNadu_df)
TamilNadu_freq_li=pd.DataFrame(TamilNadu_df["city"].value_counts())
TamilNadu_freq_li=TamilNadu_freq_li.head()
print(TamilNadu_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(TamilNadu_df["lattitude"],TamilNadu_df["longitude"]).set(title="plotting the ev stations in TamilNadu")
# Out:
#                             name      state          city  \
# 14               VEEV A2B Kallar  TamilNadu  Mettupalayam
# 15           VEEV Sathya Nursery  TamilNadu  Mettupalayam
# 68              VEEV Brookfields  TamilNadu    Coimbatore
# 139   Almond House Banjara Hills  TamilNadu     hyderabad
# 140                    Go Native  TamilNadu     bengaluru
# ...                          ...        ...           ...
# 1477                   BP-TRICHY  TamilNadu        TRICHY
# 1478            KARTHIK AGENCIES  TamilNadu        TRICHY
# 1479       SRI RAJAN ENTERPRISES  TamilNadu       MADURAI
# 1480               BP-OTHAKKADAI  TamilNadu       MADURAI
# 1503                 Tata Power   TamilNadu         Hosur
#
#                                                 address   lattitude  \
# 14           A2B, Kallar Road, Mettupalayam, Tamil Nadu     11.3217
# 15                     Kallar, Mettupalayam, Tamil Nadu       11.33
# 68    67-71, Dr Krishnasamy Mudaliyar Rd, Ram Nagar,...     11.0096
# 139   8-2-350/3/1, Next to Meena Bazar, Rd Number 3,...  17.4270191
# 140   #64, 10th Main Rd, 4th Block, 5th Block, Jayan...   12.922504
# ...                                                 ...         ...
# 1477  Bharat Petroleum Company owner retail outlet, ...    11.03248
# 1478  Bharat Petroleum Dealers, S.No-456/6, 5B, NH38...    11.00462
# 1479  Sri Rajan Enterprises, BPCL Dealers, Surakundu...    10.02184
# 1480  BP Othakadai, BPCL Retail Outlet, Kodikulam Vi...      9.9445
# 1503  True Sai, Agraharam, Survey No 46/ 1A and 47/1...  12.7170751
#
#       longitude  type
# 14    76.916300  12.0
# 15    76.902700  12.0
# 68    76.958900  12.0
# 139   78.443419   6.0
# 140   77.584760   6.0
# ...         ...   ...
# 1477  78.808010  23.0
# 1478  78.788760  23.0
# 1479  78.313520  23.0
# 1480  78.154180  23.0
# 1503  77.876026   7.0
#
# [183 rows x 7 columns]
#             city
# Chennai       48
# Coimbatore     6
# bengaluru      6
# Madurai        6
# chennai        5
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in TamilNadu')]

# %%
Kerala_df=data[data["state"]=="Kerala"]
print(Kerala_df)
Kerala_freq_li=pd.DataFrame(Kerala_df["city"].value_counts())
Kerala_freq_li=Kerala_freq_li.head()
print(Kerala_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Kerala_df["lattitude"],Kerala_df["longitude"]).set(title="plotting the ev stations in Kerala")
# Out:
#                                      name   state             city  \
# 163           Kalinga Veg Gourmet Kitchen  Kerala             pune
# 173                          Noma Talkies  Kerala        hyderabad
# 217              Cake Bee, Singaram Nagar  Kerala  tiruchirappalli
# 230   Trichi Kaveri Foods Private Limited  Kerala  tiruchirappalli
# 239                           Uma complex  Kerala          chennai
# ...                                   ...     ...              ...
# 1131             Ginger Hotel, Kazakuttom  Kerala       Trivandrum
# 1132            Malayalam Vehicles, Aluva  Kerala            Aluva
# 1468           Wyte Portico Hotel I Adoor  Kerala            Adoor
# 1541                          Tata Power   Kerala   Pathanamthitta
# 1542                          Tata Power   Kerala           Munnar
#
#                                                 address   lattitude  \
# 163   1st - 3rd Floor, House of Nosh, CTS 1365, Gula...  18.5050103
# 173   3-4-99, Nacharam - Mallapur Rd, May Flower Hig...   17.447469
# 217   Ground Floor, No.7, Singaram Nagar, Kattur, Tr...  10.7967137
# 230                      19, Main road, Annamalai Nagar  10.8330993
# 239   No 14, Professors colony extn, Indian airforce...  12.9149033
# ...                                                 ...         ...
# 1131  Ginger Hotel Trivandrum Electronics Technology...   8.5615919
# 1132  Building No 18/615/1, 615/2 Sy No 176/2, 176/3...  10.0999671
# 1468  Wyte Portico Hotel, High School Jn, Karuvatta,...   9.1621728
# 1541  MK Motors, Churulikkodu Pathanamthitta, Milan ...   9.2744022
# 1542  Gokulam Park Munnar, Power House Road, South C...  10.0297934
#
#       longitude  type
# 163   73.831624   6.0
# 173   78.571750   6.0
# 217   78.756347   6.0
# 230   78.684534   6.0
# 239   80.126647   6.0
# ...         ...   ...
# 1131  76.876393   7.0
# 1132  76.347684   7.0
# 1468  76.721936  11.0
# 1541  76.763741   7.0
# 1542  77.045859   7.0
#
# [94 rows x 7 columns]
#                     city
# Thiruvanthapuram      10
# Kochi                 10
# THIRUVANANTHAPURAM     6
# hyderabad              4
# Kozhikode              4
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Kerala')]

# %%
Karnataka_df=data[data["state"]=="Karnataka"]
print(Karnataka_df)
Karnataka_freq_li=pd.DataFrame(Karnataka_df["city"].value_counts())
Karnataka_freq_li=Karnataka_freq_li.head()
print(Karnataka_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Karnataka_df["lattitude"],Karnataka_df["longitude"]).set(title="plotting the ev stations in Karnataka")
# Out:
#                                                    name      state       city  \
# 53                            Mke Rental Circle Station  Karnataka  Bengaluru
# 54        Waterwoods Lodge & Resort AC Charging Station  Karnataka  Metikuppe
# 59    The Forum Fiza Mall AC Charging Station Mangalore  Karnataka      Thane
# 60             MSHSD Gojer Service Charging Station      Karnataka  Bengaluru
# 75                     CNV Enterprises - HP Petrol Pump  Karnataka  Bengaluru
# ...                                                 ...        ...        ...
# 1258                 Manickbag automobiles, Vidya Nagar  Karnataka      Hubli
# 1453                        Hotel Fern Zinc, Whitefield  Karnataka  Bengaluru
# 1466                  Hotel Sri Nanjundeshwara I Tumkur  Karnataka     Tumkur
# 1488                                        Charge Zone  Karnataka  Bengaluru
# 1546                                        Tata Power   Karnataka  Mangalore
#
#                                                 address   lattitude  \
# 53    Mke Rental Private Limited, NH4, Tumkur Road, ...      13.067
# 54    19, Karapura, N.Belthur Post Office, HD Kote T...     11.9377
# 59    Basement parking (B1), The Forum Fiza Mall, Ma...     12.8576
# 60         Bettadasanapura, Bengaluru, Karnataka 560100     12.8427
# 75    No 65/20,Nallurahalli Siddapura main road,Nall...     12.9653
# ...                                                 ...         ...
# 1258        VIDYA NAGAR, DIST : Hubli, Karnataka 580031   15.369541
# 1453  1528, Channasandra Main Rd, beside Global nSch...  12.9778518
# 1466  Hotel Nanjundeshwara, Veg Restaurant, NH 48, S...  13.2852419
# 1488  KA | Bengaluru | Marriott Hotel Whitefield ,Pl...  12.9792332
# 1546  Auto Matrix, Bejai, Manjusha Building, Bejai, ...   12.885716
#
#       longitude  type
# 53    77.450000  12.0
# 54    76.265500  12.0
# 59    74.838300  12.0
# 60    77.640000  12.0
# 75    77.733100  12.0
# ...         ...   ...
# 1258  75.119095   7.0
# 1453  77.756671  18.0
# 1466  77.182996  11.0
# 1488  77.728456  24.0
# 1546  74.843476   7.0
#
# [134 rows x 7 columns]
#            city
# Bangalore    32
# Banglore     18
# BANGALORE    16
# Bengaluru     6
# goa           4
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Karnataka')]

# %%
Telangana_df=data[data["state"]=="Telangana"]
print(Telangana_df)
Telangana_freq_li=pd.DataFrame(Telangana_df["city"].value_counts())
Telangana_freq_li=Telangana_freq_li.head()
print(Telangana_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Telangana_df["lattitude"],Telangana_df["longitude"]).set(title="plotting the ev stations in Telangana")
# Out:
#                                                 name      state          city  \
# 40                   HPCL Yapral DC Charging Station  Telangana  Secunderabad
# 62    HP Loyal Pump and Pantry Fuel Charging Station  Telangana  Secunderabad
# 99                     TSREDCO Test Charging Station  Telangana      HYDERBAD
# 100                  TSREDCO Test Charging Station 1  Telangana      HYDERBAD
# 143                                  Royal Airavatha  Telangana     bengaluru
# ...                                              ...        ...           ...
# 1446                       Sri Sai Dhaba - Jedcharla  Telangana         Palem
# 1447                                    Palm Meadows  Telangana     Hyderabad
# 1448                                Sohini Tech Park  Telangana     Hyderabad
# 1501                                     Tata Power   Telangana     Hyderabad
# 1502                                     Tata Power   Telangana     Hyderabad
#
#                                                 address         lattitude  \
# 40    Hindustan Petroleum Corporation Limited, Jai J...            17.502
# 62    42-601, SP NAGAR, ECIL Main Rd, SSS Tower, MJ ...           17.4677
# 99                                                  NaN           17.4123
# 100                                                 NaN           17.4125
# 143                #749/1, Near R V Engineering College  12.9223003387451
# ...                                                 ...               ...
# 1446  CW8R+Q54, Telangana 509219 Jedcharla Telangana...             16.42
# 1447  Palm Meadows Rd, Laxmi Nagar Colony, Kompally ...             17.56
# 1448  Nanakramguda Road, Financial district, Gachibo...             17.42
# 1501  Srinidhi Service Station, Nizampet, Survey No:...         17.517565
# 1502  Kona Vijay Shankar Filling Station, Bahadurpal...         17.561621
#
#       longitude  type
# 40    78.539000  12.0
# 62    78.564100  12.0
# 99    78.459800  12.0
# 100   78.460300  12.0
# 143   77.495499   6.0
# ...         ...   ...
# 1446  77.940000  21.0
# 1447  78.480000  21.0
# 1448  78.350000  21.0
# 1501  78.380926   7.0
# 1502  78.430317   7.0
#
# [82 rows x 7 columns]
#               city
# Hyderabad       31
# HYDERABAD       10
# Secunderabad     4
# bengaluru        4
# chennai          4
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Telangana')]

# %%
Gujarat_df=data[data["state"]=="Gujarat"]
print(Gujarat_df)
Gujarat_freq_li=pd.DataFrame(Gujarat_df["city"].value_counts())
Gujarat_freq_li=Gujarat_freq_li.head()
print(Gujarat_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Gujarat_df["lattitude"],Gujarat_df["longitude"]).set(title="plotting the ev stations in Gujarat")
# Out:
#                                            name    state       city  \
# 21        Mindra Polar International AC Station  Gujarat  Ahmedabad
# 30    Mindra Crispy Culture AC Charging Station  Gujarat  Ahmedabad
# 37        Mindra D S Fasteners Charging Station  Gujarat       Pune
# 48                      Mindra EV Charger Shott  Gujarat      Shela
# 67                           Z Charging Station  Gujarat   Vadodara
# ...                                         ...      ...        ...
# 1531                                Tata Power   Gujarat  Ahmedabad
# 1532                                Tata Power   Gujarat  Ahmedabad
# 1533                                Tata Power   Gujarat  Ahmedabad
# 1534                                Tata Power   Gujarat     Rajkot
# 1535                                Tata Power   Gujarat       Vapi
#
#                                                 address  lattitude  longitude  \
# 21    Rahul Tower, 4,Vraj Vihar -6 B/H, Prernatirth ...    23.0158  72.517800
# 30    Narayan Nagar Society, Narayan Nagar, Ahmedaba...    22.9989  72.559400
# 37    National Highway 27 (8B), Opp. 80 ft. Road End...     22.473  70.895000
# 48    Shott, Sindhu Bhavan Marg, Opposite Saket-3, N...    23.0436  72.482500
# 67    Sai Vihar, Abbas Tyabji Rd, Jayesh Colony, Fat...    22.3213  73.188100
# ...                                                 ...        ...        ...
# 1531  IOCL Ashtavinayak Petroleum, Hirapur, Survey N...  22.922329  72.711943
# 1532  Riya Autolink, Bodakdev, Near Rajpath Club,SG ...   23.03577  72.510000
# 1533  Yash Motors, Narol, Opp mayauri trading compan...  22.973461  72.582288
# 1534  IOCL Motamawa, Kalavad Road, Near Saraza, Opp ...  22.269902  70.741577
# 1535  Ginger Hotel, Salvav, Ginger Hotel Vapi Dream ...  20.414322  72.918090
#
#       type
# 21    12.0
# 30    12.0
# 37    12.0
# 48    12.0
# 67    12.0
# ...    ...
# 1531   7.0
# 1532   7.0
# 1533   7.0
# 1534   7.0
# 1535   7.0
#
# [78 rows x 7 columns]
#            city
# Ahmedabad    23
# Vadodara      9
# Rajkot        5
# Surat         3
# bengaluru     3
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Gujarat')]

# %%
Rajasthan_df=data[data["state"]=="Rajasthan"]
print(Rajasthan_df)
Rajasthan_freq_li=pd.DataFrame(Rajasthan_df["city"].value_counts())
Rajasthan_freq_li=Rajasthan_freq_li.head()
print(Rajasthan_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Rajasthan_df["lattitude"],Rajasthan_df["longitude"]).set(title="plotting the ev stations in Rajasthan")
# Out:
#                                                    name      state  \
# 2     Highway Xpress (Jaipur-Delhi) DC charging station  Rajasthan
# 24                     Hotel Fairmont Jaipur AC Station  Rajasthan
# 25                        The Westin Pushkar AC Charger  Rajasthan
# 49    Highway King Behror Delhi Side DC Charging Sta...  Rajasthan
# 52                 Rani Bagh Resort DC Charging Station  Rajasthan
# ...                                                 ...        ...
# 1323                        Visvakarma Hotel, Jhunhunnu  Rajasthan
# 1486                                        Charge Zone  Rajasthan
# 1504                                        Tata Power   Rajasthan
# 1505                                        Tata Power   Rajasthan
# 1506                                        Tata Power   Rajasthan
#
#              city                                            address  \
# 2          Behror  Jaipur to Delhi Road, Behror Midway, Behror, R...
# 24          Kukas  Hotel Fairmont Jaipur, Riico, 2, Jaipur Engine...
# 25        Pushkar  The Westin Pushkar Resort & Spa, Khasra No. 12...
# 49       Gajraula  Highway King Behror, NH 8, 3 Kms from behror t...
# 52    Beawar Khas  Rani Bagh Resort, N.H.8, By Pass Ajmer Road, B...
# ...           ...                                                ...
# 1323        Sikar  Visvakarma Hotel, NH 11 NH52, Near Ganpati Dha...
# 1486       Behror  RJ | Behror Village | Hotel Express Highway,Na...
# 1504       Jaipur  Clarks Collection, Govindpuri, 18, New Sangane...
# 1505       Jaipur  Akar Fourwheels, Jhotwara, Niwaru Rd, Kumasiya...
# 1506        Ajmer  Mudgal Motors, Parbatpura, Mudgal motors, Jaip...
#
#        lattitude  longitude  type
# 2        27.8751  76.276000  12.0
# 24       27.0307  75.889900  12.0
# 25       26.4547  74.504600  12.0
# 49       27.9145  76.314600  12.0
# 52        26.125  74.345900  12.0
# ...          ...        ...   ...
# 1323  27.3449069  75.602003   7.0
# 1486   27.857413  76.264046  24.0
# 1504    26.88776  75.768040   7.0
# 1505  26.9142719  75.753320   7.0
# 1506   26.409926  74.661819   7.0
#
# [68 rows x 7 columns]
#           city
# Jaipur      20
# Ajmer        4
# Udaipur      3
# Shahpura     3
# Behror       2
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Rajasthan')]

# %%
Uttar_df=data[data["state"]=="Uttar Pradesh"]
print(Uttar_df)
Uttar_freq_li=pd.DataFrame(Uttar_df["city"].value_counts())
Uttar_freq_li=Uttar_freq_li.head()
print(Uttar_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Uttar_df["lattitude"],Uttar_df["longitude"]).set(title="plotting the ev stations in Uttar Pradesh")
# Out:
#                                        name          state        city  \
# 3         Food Carnival DC Charging Station  Uttar Pradesh    Khatauli
# 4         Food Carnival AC Charging Station  Uttar Pradesh    Khatauli
# 33                 RSTV Charging Hub Meerut  Uttar Pradesh      Meerut
# 47      RSTV Saharanpur AC Charging Station  Uttar Pradesh  Saharanpur
# 51    McDonald Gajraula DC Charging Station  Uttar Pradesh    Gajraula
# ...                                     ...            ...         ...
# 1487                            Charge Zone  Uttar Pradesh     Aligarh
# 1496                            Tata Power   Uttar Pradesh       Noida
# 1497                            Tata Power   Uttar Pradesh       Noida
# 1498                            Tata Power   Uttar Pradesh      Meerut
# 1499                            Tata Power   Uttar Pradesh     Lucknow
#
#                                                 address   lattitude  \
# 3     Fun and Food Carnival, NH 58, Khatauli Bypass,...     29.3105
# 4     NH 58, Khatauli Bypass, Bhainsi, Uttar Pradesh...     29.3105
# 33                         Meerut, Uttar Pradesh 250001     28.9955
# 47    Nanak Puram Colony, Pushpanjali Vihar, Numaish...      29.977
# 51    McDonald Gajraula, NH9-24 Salarpur, Dist, Gajr...     28.8382
# ...                                                 ...         ...
# 1487  UP | Aligarh | Hotel Food Bell,Ogarnagala Rajo...  28.0236646
# 1496  Shiva Motocorp, Sec-5 , Shiva Motocorp - A Uni...   28.592257
# 1497  IOCL - COCO EPE Aurangpur, Gautam Budh Nagar, ...   28.346036
# 1498  Hyphen Premier Hotel, Major Dhyanchand Nagar, ...  28.9482803
# 1499  Pinnacle by 1589 Hotels, LDA Colony, Sector D,...  26.7737236
#
#       longitude  type
# 3     77.721800  12.0
# 4     77.721800  12.0
# 33    77.705700  12.0
# 47    77.575300  12.0
# 51    78.276400  12.0
# ...         ...   ...
# 1487  77.973842  24.0
# 1496  77.322172   7.0
# 1497  77.513608   7.0
# 1498  77.675485   7.0
# 1499  80.900508   7.0
#
# [87 rows x 7 columns]
#                city
# Noida            22
# Ghaziabad        10
# Muzaffarnagar     8
# Lucknow           7
# Agra              4
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Uttar Pradesh')]

# %%
Haryana_df=data[data["state"]=="Haryana"]
print(Haryana_df)
Haryana_freq_li=pd.DataFrame(Haryana_df["city"].value_counts())
Haryana_freq_li=Haryana_freq_li.head()
print(Haryana_freq_li) 
fig=plt.figure(figsize=(10,10))
sns.scatterplot(Haryana_df["lattitude"],Haryana_df["longitude"]).set(title="plotting the ev stations in Haryana")
# Out:
#                                      name    state       city  \
# 0      Neelkanth Star DC Charging Station  Haryana   Gurugram
# 1            Galleria DC Charging Station  Haryana   Gurugram
# 8           SG Karnal DC Charging Station  Haryana     Karnal
# 9           SG Karnal AC Charging Station  Haryana     Karnal
# 10    Neelkanth Star AC charging  station  Haryana     karnal
# ...                                   ...      ...        ...
# 1040        Daisy Motors, TML - CV, Hisar  Haryana      Hisar
# 1222              IOCL Royal Petro, NH 44  Haryana     Karnal
# 1536                          Tata Power   Haryana  Faridabad
# 1543                          Tata Power   Haryana    Gurgaon
# 1544                          Tata Power   Haryana    Gurgaon
#
#                                                 address   lattitude  \
# 0     Neelkanth Star Karnal, NH 44, Gharunda, Kutail...     29.6019
# 1     DLF Phase IV, Sector 28, Gurugram, Haryana 122022     28.4673
# 8     131 km Milestone, G. T, GT Karnal Rd, near Kar...     29.7379
# 9     131 km Milestone, G. T, GT Karnal Rd, near Kar...     29.7379
# 10    Neelkanth Star Karnal, NH 44, Gharunda, Kutail...     29.6019
# ...                                                 ...         ...
# 1040  Daisy Motors, 12th KM Stone, Delhi-Hisar Bypas...  29.1259617
# 1222  NH 44, Near The Royal Paradise Resort , Karnal...   29.731581
# 1536  AutoVikas, Sec -5, Plot no-2 Sector- 5 North I...     28.3628
# 1543  Vatika Town Square II, Sector 82, Sector 82, V...  28.3904593
# 1544  Zedex TATA, Sec 48, GF-26, NIHO Scottish Mall,...   28.411072
#
#       longitude  type
# 0     76.980300  12.0
# 1     77.081800  12.0
# 8     76.975600  12.0
# 9     76.975600  12.0
# 10    76.980300  12.0
# ...         ...   ...
# 1040  75.802782   7.0
# 1222  76.976511   7.0
# 1536  77.314851   7.0
# 1543  76.959200   7.0
# 1544  77.040546   7.0
#
# [62 rows x 7 columns]
#            city
# Gurgaon      17
# Gurugram     11
# Karnal        4
# GURUGRAM      4
# Panchkula     3
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'plotting the ev stations in Haryana')]

# %%
ap_freq_li=pd.DataFrame(ap_freq_li)
maha_freq_li=pd.DataFrame(maha_freq_li)
delhi_freq_li=pd.DataFrame(delhi_freq_li)
TamilNadu_freq_li=pd.DataFrame(TamilNadu_freq_li)
Kerala_freq_li=pd.DataFrame(Kerala_freq_li)
Karnataka_freq_li=pd.DataFrame(Karnataka_freq_li)
Telangana_freq_li=pd.DataFrame(Telangana_freq_li)
Gujarat_freq_li=pd.DataFrame(Gujarat_freq_li)
Rajasthan_freq_li=pd.DataFrame(Rajasthan_freq_li)
Uttar_freq_li=pd.DataFrame(Uttar_freq_li)
Haryana_freq_li=pd.DataFrame(Haryana_freq_li)

# %%
c=pd.concat([ ap_freq_li, maha_freq_li ,delhi_freq_li,TamilNadu_freq_li,Kerala_freq_li,Karnataka_freq_li,Telangana_freq_li,Gujarat_freq_li,
            Rajasthan_freq_li,Uttar_freq_li,Haryana_freq_li], 
            keys={ 'AndhraPradesh' : ap_freq_li, 'Maharashtra' : maha_freq_li ,"Delhi":delhi_freq_li,"TamilNadu":TamilNadu_freq_li,
                  "Kerala":Kerala_freq_li,"karnataka":Karnataka_freq_li,"Telangana":Telangana_freq_li,"Gujarat":Gujarat_freq_li,
            "Rajasthan":Rajasthan_freq_li,"UttarPradesh":Uttar_freq_li,"Haryana":Haryana_freq_li})
c
# Out:
#                                   city
# AndhraPradesh Tirupati               6
#               Kurnool                6
#               Vizag                  6
#               Chittoor               4
#               Rajahmundry            3
# Maharashtra   Mumbai                45
#               Pune                  34
#               Nashik                15
#               bengaluru             12
#               Navi Mumbai            7
# Delhi         Delhi                 70
#               New Delhi             67
#               Gurgaon                9
#               NEW DELHI              6
#               pune                   3
# TamilNadu     Chennai               48
#               Coimbatore             6
#               bengaluru              6
#               Madurai                6
#               chennai                5
# Kerala        Thiruvanthapuram      10
#               Kochi                 10
#               THIRUVANANTHAPURAM     6
#               hyderabad              4
#               Kozhikode              4
# karnataka     Bangalore             32
#               Banglore              18
#               BANGALORE             16
#               Bengaluru              6
#               goa                    4
# Telangana     Hyderabad             31
#               HYDERABAD             10
#               Secunderabad           4
#               bengaluru              4
#               chennai                4
# Gujarat       Ahmedabad             23
#               Vadodara               9
#               Rajkot                 5
#               Surat                  3
#               bengaluru              3
# Rajasthan     Jaipur                20
#               Ajmer                  4
#               Udaipur                3
#               Shahpura               3
#               Behror                 2
# UttarPradesh  Noida                 22
#               Ghaziabad             10
#               Muzaffarnagar          8
#               Lucknow                7
#               Agra                   4
# Haryana       Gurgaon               17
#               Gurugram              11
#               Karnal                 4
#               GURUGRAM               4
#               Panchkula              3
